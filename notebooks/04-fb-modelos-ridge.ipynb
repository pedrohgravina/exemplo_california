# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import ElasticNet, LinearRegression, Ridge
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (
    OrdinalEncoder,
    OneHotEncoder,
    PolynomialFeatures,
    PowerTransformer,
    RobustScaler,
    StandardScaler,
    QuantileTransformer,
)

from sklearn import set_config
set_config(display="text")

from src.config import DADOS_LIMPOS
from src.auxiliares import dataframe_coeficientes
from src.graficos import (
    plot_coeficientes,
    plot_comparar_metricas_modelos,
    plot_residuos_estimador,
)
from src.models import (
    organiza_resultados,
    treinar_e_validar_modelo_regressao,
    grid_search_cv_regressor,
)

# %%
df = pd.read_parquet(DADOS_LIMPOS)

df.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2        1206         595         2.0804              226700        NEAR BAY
# 3         697         264         2.1250              140000        NEAR BAY
# 4         990         419         1.9911              158700        NEAR BAY
#
#    median_income_cat  rooms_per_household  population_per_household  \
# 0                  5             6.984127                  2.555556
# 1                  5             6.238137                  2.109842
# 2                  2             4.294117                  2.026891
# 3                  2             4.242424                  2.640152
# 4                  2             5.343676                  2.362768
#
#    bedrooms_per_room
# 0           0.146591
# 1           0.155797
# 2           0.260274
# 3           0.252679
# 4           0.203216

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17564 entries, 0 to 17563
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   longitude                 17564 non-null  float32
#  1   latitude                  17564 non-null  float32
#  2   housing_median_age        17564 non-null  int8
#  3   total_rooms               17564 non-null  int16
#  4   total_bedrooms            17564 non-null  int16
#  5   population                17564 non-null  int16
#  6   households                17564 non-null  int16
#  7   median_income             17564 non-null  float32
#  8   median_house_value        17564 non-null  int32
#  9   ocean_proximity           17564 non-null  category
#  10  median_income_cat         17564 non-null  int64
#  11  rooms_per_household       17564 non-null  float32
#  12  population_per_household  17564 non-null  float32
#  13  bedrooms_per_room         17564 non-null  float32
# dtypes: category(1), float32(6), int16(4), int32(1), int64(1), int8(1)
# memory usage: 789.3 KB

# %%
coluna_target = ["median_house_value"]

coluna_one_hot_encoder = ["ocean_proximity"]

coluna_ordinal_encoder = ["median_income_cat"]

# %%
colunas_robust_scaler = df.columns.difference(coluna_target + coluna_one_hot_encoder + coluna_ordinal_encoder)

colunas_robust_scaler
# Out:
# Index(['bedrooms_per_room', 'households', 'housing_median_age', 'latitude',
#        'longitude', 'median_income', 'population', 'population_per_household',
#        'rooms_per_household', 'total_bedrooms', 'total_rooms'],
#       dtype='object')

# %%
# Criei um pipeline pra usar o PolynomialFeatures (regressor) junto como o RobustScaler (preprocessamento)
pipeline_robust = Pipeline([
    ("robust_scaler", RobustScaler()),
    ("poly", PolynomialFeatures(degree=1, include_bias=False))
])

preprocessamento = ColumnTransformer(
    transformers=[
        ("ordinal_encoder", OrdinalEncoder(categories="auto"), coluna_ordinal_encoder),
        ("one_hot", OneHotEncoder(drop="first"), coluna_one_hot_encoder),
        ("robust_scaler_poly", pipeline_robust, colunas_robust_scaler),
    ],
)

# %%
X = df.drop(columns=coluna_target)
y = df[coluna_target]

# %%
X.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income ocean_proximity  median_income_cat  \
# 0         322         126         8.3252        NEAR BAY                  5
# 1        2401        1138         8.3014        NEAR BAY                  5
# 2        1206         595         2.0804        NEAR BAY                  2
# 3         697         264         2.1250        NEAR BAY                  2
# 4         990         419         1.9911        NEAR BAY                  2
#
#    rooms_per_household  population_per_household  bedrooms_per_room
# 0             6.984127                  2.555556           0.146591
# 1             6.238137                  2.109842           0.155797
# 2             4.294117                  2.026891           0.260274
# 3             4.242424                  2.640152           0.252679
# 4             5.343676                  2.362768           0.203216

# %%
y.head()
# Out:
#    median_house_value
# 0              452600
# 1              358500
# 2              226700
# 3              140000
# 4              158700

# %%
param_grid = {
    "regressor__preprocessor__robust_scaler_poly__poly__degree": [1, 2, 3],
    "regressor__reg__alpha": [1E-2, 5E-2, 0.1, 0.25, 1.0, 2.0, 5.0, 10.0, 20.0, 50.0],
}

# %%
grid_search = grid_search_cv_regressor(
    regressor=Ridge(),
    preprocessor=preprocessamento,
    target_transformer=QuantileTransformer(output_distribution="normal"),
    param_grid=param_grid,
)

grid_search
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pipeline(steps=[('robust_scaler',
#                                                                                                                                Ro...
#                                                                              Ridge())]),
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-1,
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3],
#                          'regressor__reg__alpha': [0.01, 0.05, 0.1, 0.25, 1.0,
#                                                    2.0, 5.0, 10.0, 20.0,
#                                                    50.0]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pipeline(steps=[('robust_scaler',
#                                                                                                                                Ro...
#                                                                              Ridge())]),
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-1,
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3],
#                          'regressor__reg__alpha': [0.01, 0.05, 0.1, 0.25, 1.0,
#                                                    2.0, 5.0, 10.0, 20.0,
#                                                    50.0]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.best_params_
# Vemos que o alfa pego foi o melhor, ou seja, houve uma grnade regularização
# Out:
# {'regressor__preprocessor__robust_scaler_poly__poly__degree': 3,
#  'regressor__reg__alpha': 20.0}

# %%
grid_search.best_score_ # Houve uma melhora considerável
# Out:
# np.float64(-50445.067963107875)

# %%
coefs = dataframe_coeficientes(
    grid_search.best_estimator_.regressor_["reg"].coef_,
    grid_search.best_estimator_.regressor_["preprocessor"].get_feature_names_out(),
)

coefs
# Out:
#                                                     coeficiente
# robust_scaler_poly__longitude                         -0.889830
# robust_scaler_poly__latitude                          -0.794406
# one_hot__ocean_proximity_INLAND                       -0.498202
# robust_scaler_poly__population_per_household          -0.333378
# robust_scaler_poly__latitude^2                        -0.290944
# ...                                                         ...
# robust_scaler_poly__housing_median_age longitude^2     0.192571
# robust_scaler_poly__latitude median_income popu...     0.217551
# robust_scaler_poly__housing_median_age median_i...     0.245012
# robust_scaler_poly__bedrooms_per_room                  0.317739
# robust_scaler_poly__median_income                      0.972969
#
# [367 rows x 1 columns]

# %%
plot_coeficientes(coefs)

# %%
coefs[coefs["coeficiente"] == 0] # Ainda temos uma regularização Lasso, então podemos ver que alguns coeficientes foram zerados.
# Out:
# Empty DataFrame
# Columns: [coeficiente]
# Index: []

# %%
coefs[coefs["coeficiente"].between(-0.2, 0.2)]
# Out:
#                                                     coeficiente
# one_hot__ocean_proximity_NEAR BAY                     -0.197388
# robust_scaler_poly__longitude^2 rooms_per_house...    -0.176539
# robust_scaler_poly__latitude^2 population             -0.172977
# robust_scaler_poly__housing_median_age median_i...    -0.171113
# robust_scaler_poly__latitude^2 median_income          -0.168808
# ...                                                         ...
# robust_scaler_poly__latitude^3                         0.170461
# robust_scaler_poly__bedrooms_per_room median_in...     0.173785
# robust_scaler_poly__longitude median_income pop...     0.186856
# robust_scaler_poly__latitude^2 longitude               0.187673
# robust_scaler_poly__housing_median_age longitude^2     0.192571
#
# [350 rows x 1 columns]

# %%
plot_coeficientes(coefs[~coefs["coeficiente"].between(-0.2, 0.2)])
# Com a regularização nós notamos que as features de maior relevância (a regularização elimina essas features com pouca relevância
# ... facilitando a explicação para o cliente.
# Daí as features que envolvem renda e localização aparecem

# %%
regressors = {
    "DummyRegressor": {
        "preprocessor": None,
        "regressor": DummyRegressor(strategy="mean"),
        "target_transformer": None,
    },
    "LinearRegression": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": None,
    },
    "LinearRegression_target": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": QuantileTransformer(output_distribution="normal"),
    },
    "Ridge_grid_search": {
        "preprocessor": grid_search.best_estimator_.regressor_["preprocessor"],
        "regressor": grid_search.best_estimator_.regressor_["reg"],
        "target_transformer": grid_search.best_estimator_.transformer_,
    },
}


resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors.items()
}

df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
#                       model  fit_time score_time   test_r2  \
# 0            DummyRegressor  0.003011   0.003353 -0.000081
# 1            DummyRegressor  0.000999        0.0 -0.000146
# 2            DummyRegressor       0.0   0.006872 -0.001737
# 3            DummyRegressor       0.0        0.0 -0.000101
# 4            DummyRegressor   0.00793   0.002006 -0.000114
# 5          LinearRegression  0.009122    0.01567  0.682162
# 6          LinearRegression  0.023891   0.001874   0.66999
# 7          LinearRegression   0.01506   0.015774  0.649247
# 8          LinearRegression  0.015691        0.0  0.669873
# 9          LinearRegression  0.015904   0.015728  0.669023
# 10  LinearRegression_target  0.031357        0.0  0.691715
# 11  LinearRegression_target   0.03165   0.008641  0.678472
# 12  LinearRegression_target  0.024879        0.0  0.653759
# 13  LinearRegression_target  0.031797        0.0  0.683284
# 14  LinearRegression_target  0.031996        0.0  0.683031
# 15        Ridge_grid_search  0.872313   0.007404  0.744079
# 16        Ridge_grid_search  0.859801   0.015761  0.723921
# 17        Ridge_grid_search  0.975564   0.015629  0.697965
# 18        Ridge_grid_search  0.899398   0.017809  0.725274
# 19        Ridge_grid_search  0.824653        0.0  0.725957
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -77516.042766                    -96239.705692     0.006363
# 1                 -75787.787194                    -95217.629397     0.000999
# 2                 -76753.598961                    -96253.253947     0.006872
# 3                 -76837.804811                    -95983.885799          0.0
# 4                 -76617.245449                    -96182.764729     0.009936
# 5                 -39855.690996                    -54254.958188     0.024792
# 6                 -40272.565467                    -54695.230283     0.025766
# 7                  -42178.05929                    -56955.988706     0.030834
# 8                 -40806.492497                    -55146.318803     0.015691
# 9                 -40788.496497                     -55331.35106     0.031632
# 10                -37804.944352                    -53433.449406     0.031357
# 11                 -38292.57501                    -53987.721595     0.040291
# 12                 -40297.18199                    -56588.435746     0.024879
# 13                -38595.868144                      -54014.5799     0.031797
# 14                -38412.799379                    -54147.821937     0.031996
# 15                 -34141.68496                    -48684.362409     0.879717
# 16                -35032.859151                    -50026.745601     0.875562
# 17                -37084.402367                    -52852.651428     0.991194
# 18                -35291.750073                    -50306.764848     0.917207
# 19                -35291.969925                    -50347.908157     0.824653

# %% [markdown]
# * Notamos uma melhora nas métricas, mas o tempo aumenta consideravelmente (O modelo fica mais pesado)

# %%
df_resultados.groupby("model").mean()
# Out:
#                          fit_time score_time   test_r2  \
# model
# DummyRegressor           0.002388   0.002446 -0.000436
# LinearRegression         0.015934   0.009809  0.668059
# LinearRegression_target  0.030336   0.001728  0.678052
# Ridge_grid_search        0.886346   0.011321  0.723439
#
#                         test_neg_mean_absolute_error  \
# model
# DummyRegressor                         -76702.495836
# LinearRegression                        -40780.26095
# LinearRegression_target                -38680.673775
# Ridge_grid_search                      -35368.533295
#
#                         test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                             -95975.447913     0.004834
# LinearRegression                           -55276.769408     0.025743
# LinearRegression_target                    -54434.401717     0.032064
# Ridge_grid_search                          -50443.686489     0.897667

# %%
df_resultados.groupby("model").mean().sort_values(by="test_neg_root_mean_squared_error")
# Out:
#                          fit_time score_time   test_r2  \
# model
# DummyRegressor           0.002388   0.002446 -0.000436
# LinearRegression         0.015934   0.009809  0.668059
# LinearRegression_target  0.030336   0.001728  0.678052
# Ridge_grid_search        0.886346   0.011321  0.723439
#
#                         test_neg_mean_absolute_error  \
# model
# DummyRegressor                         -76702.495836
# LinearRegression                        -40780.26095
# LinearRegression_target                -38680.673775
# Ridge_grid_search                      -35368.533295
#
#                         test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                             -95975.447913     0.004834
# LinearRegression                           -55276.769408     0.025743
# LinearRegression_target                    -54434.401717     0.032064
# Ridge_grid_search                          -50443.686489     0.897667

# %%
plot_comparar_metricas_modelos(df_resultados) # O tempo ficou alto, mas bem mais baixo que o da ElasticNet e ainda melhorou a métrica.

# %%
plot_residuos_estimador(grid_search.best_estimator_, X, y, fracao_amostra=0.1, eng_formatter=True)
